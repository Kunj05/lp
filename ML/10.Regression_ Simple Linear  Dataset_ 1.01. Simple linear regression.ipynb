# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/1.01. Simple linear regression.csv");
df
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
df.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
df.tail()
# Out:
#      SAT   GPA
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SAT     84 non-null     int64
#  1   GPA     84 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.4 KB

# %%
df.isnull().sum()
# Out:
# SAT    0
# GPA    0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error


x=df[["SAT"]]
y=df[["GPA"]]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

model=LinearRegression()
model.fit(x_train,y_train);

y_pred=model.predict(x_test)

print(f"Coefficient(Slope): {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")

print(f"Mean Squared Error: {r2_score(y_test, y_pred)}")
print(f"Coefficient of Determination (R²): {mean_squared_error(y_test, y_pred)}")
# Out:
# Coefficient(Slope): [0.00165734]
# Intercept: [0.25749806]
# Mean Squared Error: 0.26052688391354584
# Coefficient of Determination (R²): 0.026399446117336977

# %%
import matplotlib.pyplot as plt

# Plot the actual data points
plt.scatter(x_train, y_train, color='blue', label='Actual Data')

# Plot the regression line (using the model's predictions)
plt.plot(x_test, model.predict(x_test), color='red', label='Regression Line')

plt.title("SAT Score vs GPA")
plt.xlabel("SAT Score")
plt.ylabel("GPA")
plt.legend()


plt.show()
